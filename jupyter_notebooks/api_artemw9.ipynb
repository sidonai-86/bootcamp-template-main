# %%
import requests
import pyarrow
import pandas as pd
import datetime as dt

# %%
load_date = dt.date.today()
url = "https://api.open-meteo.com/v1/forecast"

# %%
response = requests.get( 
    url,  
    params = {   
        "latitude" : 45.3,
        "longitude" : 75.45,
        "hourly" : [ "cloud_cover" ,"surface_pressure","weather_code"],
        "start_date" : "2025-12-01",
        "end_date" : "2026-01-01" 
    } )

# %%
response.raise_for_status()

# %%
data = response.json()
print(data)
# Out:
# {'latitude': 45.25, 'longitude': 75.5, 'generationtime_ms': 4.521846771240234, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 368.0, 'hourly_units': {'time': 'iso8601', 'cloud_cover': '%', 'surface_pressure': 'hPa', 'weather_code': 'wmo code'}, 'hourly': {'time': ['2025-12-01T00:00', '2025-12-01T01:00', '2025-12-01T02:00', '2025-12-01T03:00', '2025-12-01T04:00', '2025-12-01T05:00', '2025-12-01T06:00', '2025-12-01T07:00', '2025-12-01T08:00', '2025-12-01T09:00', '2025-12-01T10:00', '2025-12-01T11:00', '2025-12-01T12:00', '2025-12-01T13:00', '2025-12-01T14:00', '2025-12-01T15:00', '2025-12-01T16:00', '2025-12-01T17:00', '2025-12-01T18:00', '2025-12-01T19:00', '2025-12-01T20:00', '2025-12-01T21:00', '2025-12-01T22:00', '2025-12-01T23:00', '2025-12-02T00:00', '2025-12-02T01:00', '2025-12-02T02:00', '2025-12-02T03:00', '2025-12-02T04:00', '2025-12-02T05:00', '2025-12-02T06:00', '2025-12-02T07:00', '2025-12-02T08:00', '2025-12-02T09:00', '2025-12-02
# ...

# %%
filename_csv = f"api_artemw9_response_{load_date}.csv"
filename_parquet= f"api_artemw9_response_{load_date}.parquet"

# %%
df = pd.DataFrame({
    'datetime':data['hourly']['time'],
    'cloud_cover':data['hourly']["cloud_cover"],
    'surface_pressure': data['hourly']["surface_pressure"],
    'weather_code': data['hourly']["weather_code"],

})
df["upload_date"] = load_date
df.to_csv(filename_csv, sep=';' ,index = False)
df.to_parquet(filename_parquet ,index = False)
df
# Out:
#              datetime  cloud_cover  surface_pressure  weather_code upload_date
# 0    2025-12-01T00:00            0             985.7             0  2026-01-18
# 1    2025-12-01T01:00            0             985.6             0  2026-01-18
# 2    2025-12-01T02:00           59             985.6             2  2026-01-18
# 3    2025-12-01T03:00           66             985.6            45  2026-01-18
# 4    2025-12-01T04:00           66             985.6            48  2026-01-18
# ..                ...          ...               ...           ...         ...
# 763  2026-01-01T19:00          100             979.9             3  2026-01-18
# 764  2026-01-01T20:00          100             979.7             3  2026-01-18
# 765  2026-01-01T21:00          100             979.4             3  2026-01-18
# 766  2026-01-01T22:00          100             979.1             3  2026-01-18
# 767  2026-01-01T23:00          100             978.8             3  2026-01-18
#
# [768 rows x 5 columns]

# %%
ls -la
# Out:
# total 92
# drwxr-xr-x 2 root  root   4096 Jan 18 20:58 ./
# drwx------ 3 coder coder  4096 Jan 18 20:53 ../
# -rw-r--r-- 1 root  root  36878 Jan 18 21:26 api_artemw9.ipynb
# -rw-r--r-- 1 root  root  30282 Jan 18 21:26 api_artemw9_response_2026-01-18.csv
# -rw-r--r-- 1 root  root  11133 Jan 18 21:26 api_artemw9_response_2026-01-18.parquet
