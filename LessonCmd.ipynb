# %% [markdown]
# ## Основы навигации по файловой системе

# %% [markdown]
# `pwd` — показать текущую директорию

# %%
# !pwd

# %% [markdown]
# `ls` — отобразить содержимое текущей директории

# %%
# !ls

# %% [markdown]
# `ls -la` — показать подробную информацию, включая скрытые файлы

# %%
# !ls -l -a

# %%
# !ls -la

# %%
# !ls /home/

# %% [markdown]
# `cd /path/to/dir` — перейти в указанную директорию

# %%
# !cd /path/to/dir

# %% [markdown]
# `cd ..` — подняться на уровень выше

# %%
# !cd ..

# %% [markdown]
# `mkdir new_dir` — создать новую директорию

# %%
# !mkdir new_dir

# %% [markdown]
# `rm -r dir_name` — рекурсивно удалить папку и её содержимое

# %%
rm -r new_dir

# %% [markdown]
# ## Работа с файлами

# %% [markdown]
# `touch file.txt` — создать файл

# %%
# !touch file_old.txt

# %% [markdown]
# `mv old new` — переименовать или переместить файл или папку

# %%
# !mv file_old.txt file_new.txt

# %% [markdown]
# `cp file newfile` — копировать файл

# %%
# !cp file_new.txt file.txt

# %%
# создаем строки в файле для дальнейших упражнений
# !echo "string 1" >> file.txt
# !echo "string 2" >> file.txt
# !echo "string 3" >> file.txt
# !echo "string 4" >> file.txt
# !echo "string 5" >> file.txt
# !echo "string 6" >> file.txt
# !echo "string 7" >> file.txt
# !echo "string 8" >> file.txt
# !echo "string 9" >> file.txt
# !echo "string 10" >> file.txt
# !echo "string 11" >> file.txt
# !echo "string 12" >> file.txt

# %% [markdown]
# `cat file.txt` — вывести содержимое файла

# %%
# !cat file.txt

# %% [markdown]
# `head file.txt` — показать первые 10 строк файла

# %%
# !head file.txt

# %% [markdown]
# `tail file.txt` — показать последние 10 строк файла

# %%
# !tail file.txt

# %% [markdown]
# `tail -f file.txt` — с флагом -f в режиме реального времени (если, например, файл продолжает наполняться данными).

# %%
# !tail -f file.txt

# %%
# При работе предыдущей ячейки выполни эту команду в терминале
# !echo "string 14" >> file.txt

# %% [markdown]
# `less file.txt` — постраничный просмотр файла

# %%
# команда для терминала
# !less file.txt

# %% [markdown]
# `grep "pattern" file.txt` — найти строки, содержащие шаблон

# %%
# !grep "3" file.txt

# %% [markdown]
# `rm file.txt` — удалить файл

# %%
# !rm file_new.txt

# %% [markdown]
# ## Работа с архивами

# %% [markdown]
# `tar -czf archive.tar.gz folder/` — создать tar.gz архив

# %%
# -czf create zip file
# !tar -czf archive.tar.gz file.txt

# %% [markdown]
# `tar -xzf archive.tar.gz` — распаковать архив

# %%
# !rm file.txt

# %%
# extract zip file
# !tar -xzf archive.tar.gz

# %% [markdown]
# ## Работа с правами доступа

# %% [markdown]
# Давайте посмотрим на вывод следующей команды. Нас интерисует начало

# %%
# !chmod 777 file.txt
# !ls -l ./file.txt

# %% [markdown]
# # Что означает `-rwxrwxrwx`
#
# - Первый символ — тип файла:
#   - `-` — обычный файл
#   - `d` — директория (папка)
#   - `l` — символическая ссылка (по сути это когда вы ссылаететь на файл из другого каталога)
#
# - Следующие 9 символов разделены на три группы по три символа каждая:
#
# | Позиция        | Символы | Значение                           |
# |----------------|---------|----------------------------------|
# | 1–3 (владелец) | `rwx`   | Чтение (r), запись (w), выполнение (x) для владельца файла |
# | 4–6 (группа)   | `rwx`   | Те же права для группы пользователей файла                  |
# | 7–9 (остальные)| `rwx`   | Те же права для всех остальных пользователей                 |

# %% [markdown]
# `chmod -x script.sh` — убираем право на исполнение файла

# %%
# !chmod -x file.txt
# !ls -l ./file.txt

# %% [markdown]
# `chmod +x script.sh` — убираем право на исполнение файла

# %%
# !chmod +x file.txt
# !ls -l ./file.txt

# %% [markdown]
# `chmod 644 file.txt` — установить права доступа

# %%
# !chmod 764 file.txt
# !ls -l ./file.txt

# %% [markdown]
# ## Работа с сетью

# %% [markdown]
# `ping google.com` — проверить соединение

# %%
# !ping google.com

# %% [markdown]
# `curl http://example.com` — сделать HTTP-запрос

# %%
# !curl 'http://clickhouse01:8123/'

# %% [markdown]
# `wget http://url/file` — скачать файл по ссылке

# %%
# !wget https://github.com/halltape/HalltapeRoadmapDE/archive/refs/heads/main.zip

# %% [markdown]
# ## Перенаправление

# %% [markdown]
# `command > file.txt` — перенаправить вывод в файл (перезапись)

# %%
# !echo '123' > file.txt

# %% [markdown]
# `command >> file.txt` — перенаправить вывод в файл (добавление)

# %%
# !echo '123' >> file.txt

# %% [markdown]
# ## Поиск файлов

# %% [markdown]
# `find . -name "*.csv"` — найти все .csv файлы

# %%
# !find ./ -name "*.ipynb"

# %% [markdown]
# `find /path -type f -size +10M` — найти файлы > 10MB

# %%
# !find ./ -type f -size +10M

# %% [markdown]
# ## Дополнительное

# %% [markdown]
# `history` — история команд

# %%
history

# %% [markdown]
# `echo` — история команд

# %%
# !echo "какой-то текст"

# %%
# !echo $JUPYTERHUB_USER

# %% [markdown]
# `env` - выводит информацию о переменном окружении

# %%
env
